# %% [markdown]
# <a href="https://colab.research.google.com/github/Ester-Taniya/DI-Bootcamp/blob/main/Week4%20/Day5/w4d5_Daily_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data= pd.read_csv('ds_salaries.csv')

# %%
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# This data is structured because it is a table with a specific schema, include numerical columns, categorical columns, and well-defined relationships.
# it's can be analasyse with traditional statistical methods and visualize data using charts, histograms, and other graphical tools.

# %%
# cheack duplicates to delite
duplicated_rows = data[data.duplicated(keep=False)]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
# cheack Nan values to delite
rows_with_nan = data[data.isna().any(axis=1)]
rows_with_nan
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
grouped_data = data.groupby('experience_level')

# %%
#the mean salaries for each group
mean_salary=grouped_data['salary_in_usd'].mean().sort_values()
mean_salary
# Out:
# experience_level
# EN     61643.318182
# MI     87996.056338
# SE    138617.292857
# EX    199392.038462
# Name: salary_in_usd, dtype: float64

# %%
#the median salaries for each group
median_salary=grouped_data['salary_in_usd'].median().sort_values()
median_salary
# Out:
# experience_level
# EN     56500.0
# MI     76940.0
# SE    135500.0
# EX    171437.5
# Name: salary_in_usd, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ax = mean_salary.plot(kind='bar', color=palette)
ax.set_xticklabels(['Entry', 'Middle', 'Senior', 'Expert'])

plt.xlabel('Experience Level')
plt.ylabel('Average Salary')
plt.title('Average Salary by Experience Level ')


for i, v in enumerate(mean_salary):
    ax.text(i, v + 500, str(round(v, 2)), color='black', ha='center', va='bottom')

plt.show()
