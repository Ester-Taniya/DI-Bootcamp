# %% [markdown]
# <a href="https://colab.research.google.com/github/Ester-Taniya/DI-Bootcamp/blob/main/Week6/Day3/xp_w6_d3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
🌟 Exercise 1 : Basic Usage Of SciPy

Instructions

Import the SciPy library and explore its version.

# %%
import scipy

# Print the version of SciPy
print("SciPy Version:", scipy.__version__)
# Out:
# SciPy Version: 1.11.4

# %% [markdown]
# 🌟 Exercise 2 : Descriptive Statistics
#
# Instructions
#
# Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample dataset in code:
#
#
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
import scipy.stats

data = [12, 15, 13, 12, 18, 20, 22, 21]

mean_value = scipy.mean(data)

median_value = scipy.median(data)

variance_value = scipy.var(data)

std_dev_value = scipy.std(data)

print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Variance: {variance_value}")
print(f"Standard Deviation: {std_dev_value:}")
# Out:
# Mean: 16.625
# Median: 16.5
# Variance: 14.984375
# Standard Deviation: 3.8709656418005056
# <ipython-input-8-5622bd473245>:5: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#   mean_value = scipy.mean(data)
# <ipython-input-8-5622bd473245>:7: DeprecationWarning: scipy.median is deprecated and will be removed in SciPy 2.0.0, use numpy.median instead
#   median_value = scipy.median(data)
# <ipython-input-8-5622bd473245>:9: DeprecationWarning: scipy.var is deprecated and will be removed in SciPy 2.0.0, use numpy.var instead
#   variance_value = scipy.var(data)
# <ipython-input-8-5622bd473245>:11: DeprecationWarning: scipy.std is deprecated and will be removed in SciPy 2.0.0, use numpy.std instead
#   std_dev_value = scipy.std(data)

# %% [markdown]
# 🌟 Exercise 3 : Understanding Distributions
#
# Instructions
#
# Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean_value = 50
std_dev_value = 10

normal_distribution = norm(loc=mean_value, scale=std_dev_value)

x_values = np.linspace(mean_value - 3 * std_dev_value, mean_value + 3 * std_dev_value, 1000)

plt.plot(x_values, normal_distribution.pdf(x_values), label=f'Mean={mean_value}, Std Dev={std_dev_value}')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density Function (PDF)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 🌟 Exercise 4 : T-Test Application
#
# Instructions
#
# Perform a T-test on two sets of randomly generated data. Hint: Use numpy.random.normal() to generate the datasets.

# %%
import numpy as np
from scipy.stats import ttest_ind


np.random.seed(0) # random number

data1 = np.random.normal(loc=50, scale=10, size=100) # random numbers
data2 = np.random.normal(loc=51, scale=11, size=100) # random numbers

# Perform T-test
t_statistic, p_value = ttest_ind(data1, data2)

# Print the results
print(f'T-statistic: {t_statistic:.4f}')
print(f'P-value: {p_value:.4f}')

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("The difference between the two datasets is statistically significant. Reject the null hypothesis.")
else:
    print("There is not enough evidence to reject the null hypothesis.")
# Out:
# T-statistic: -0.8535
# P-value: 0.3944
# There is not enough evidence to reject the null hypothesis.
