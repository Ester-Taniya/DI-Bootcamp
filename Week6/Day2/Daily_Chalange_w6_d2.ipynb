# %% [markdown]
# <a href="https://colab.research.google.com/github/Ester-Taniya/DI-Bootcamp/blob/main/Week6/Day2/Daily_Chalange_w6_d2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NumPy, Pandas & Matplotlib Integration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
data = pd.read_csv('global_power_plant_database.csv')

data.head(10)
# Out:
# <ipython-input-9-66ec36ceed0f>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('global_power_plant_database.csv')
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                       Kandahar DOG
# 2     AFG  Afghanistan                                       Kandahar JOL
# 3     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 5     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 6     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
# 7     AFG  Afghanistan  Pul-e-Khumri Hydroelectric Power Plant Afghani...
# 8     AFG  Afghanistan   Sarobi Dam Hydroelectric Power Plant Afghanistan
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         34936 non-null  object
#  1   country_long                    34936 non-null  object
#  2   name                            34936 non-null  object
#  3   gppd_idnr                       34936 non-null  object
#  4   capacity_mw                     34936 non-null  float64
#  5   latitude                        34936 non-null  float64
#  6   longitude                       34936 non-null  float64
#  7   primary_fuel                    34936 non-null  object
#  8   other_fuel1                     1944 non-null   object
#  9   other_fuel2                     276 non-null    object
#  10  other_fuel3                     92 non-null     object
#  11  commissioning_year              17447 non-null  float64
# ...

# %%
data.fillna(value=np.nan, inplace=True)
data
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# 34933     ZMB       Zambia                                     Victoria Falls
# 34934     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 34935     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
# ...

# %%
data['capacity_mw'] = pd.to_numeric(data['capacity_mw'], errors='coerce')
data['year_of_capacity_data'] = pd.to_numeric(data['year_of_capacity_data'], errors='coerce')

# %%
#Exploratory Data Analysis:

numerical_summary = data.describe()
numerical_summary
# Out:
#         capacity_mw      latitude     longitude  commissioning_year  \
# count  34936.000000  34936.000000  34936.000000        17447.000000
# mean     163.355148     32.816637     -6.972803         1997.414823
# std      489.636072     22.638603     78.405850           23.397835
# min        1.000000    -77.847000   -179.977700         1896.000000
# 25%        4.900000     29.256475    -77.641550         1988.000000
# 50%       16.745000     39.727750     -2.127100         2007.000000
# 75%       75.344250     46.263125     49.502675         2014.000000
# max    22500.000000     71.292000    179.388700         2020.000000
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count           14887.000000          6417.000000          7226.000000
# mean             2018.218849           592.696107           656.863891
# std                 1.606428          2174.833482          2231.464288
# ...

# %%
# distribution of power plants by country and fuel type
grouped_by_fuel = data.groupby('country_long')['primary_fuel'].value_counts()
print(grouped_by_fuel)
# Out:
# country_long  primary_fuel
# Afghanistan   Hydro           6
#               Solar           2
#               Gas             1
# Albania       Hydro           7
#               Other           1
#                              ..
# Zambia        Biomass         1
#               Coal            1
#               Solar           1
# Zimbabwe      Coal            1
#               Hydro           1
# Name: primary_fuel, Length: 698, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

grouped_by_fuel = data.groupby(['country_long', 'primary_fuel']).size().unstack(fill_value=0)

# Create a stacked bar plot
plt.figure(figsize=(14, 8))
grouped_by_fuel.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Distribution of Power Plants by Country and Fuel Type')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.legend(title='Fuel Type', loc='upper right')
plt.show()

# %%
t_stat, p_val = stats.ttest_ind(solar_power, wind_power)


if 'year_of_capacity_data' in data.columns:
    # Group data by year and primary fuel, and create a DataFrame with counts
    fuel_type_over_time = data.groupby(['year_of_capacity_data', 'primary_fuel']).size().unstack().fillna(0)

if 'latitude' in data.columns and 'longitude' in data.columns:

    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='longitude', y='latitude', hue='primary_fuel', data=data)
    plt.title('Geographical Distribution of Power Plants')
    plt.show()  # Display the plot

# %%
# Statistical Analysis: of power output by fuel type
power_stats = data.groupby('primary_fuel')['capacity_mw'].agg([np.mean, np.std, np.min, np.max])

power_stats
# Out:
#                        mean          std  amin      amax
# primary_fuel
# Biomass           23.972938    39.461805   1.0    528.00
# Coal             843.579828   888.187187   1.2   7000.00
# Cogeneration      98.731707   283.428252   1.6   1404.00
# Gas              373.449375   560.934146   1.0   8865.00
# Geothermal        67.130952   114.640890   1.0   1163.00
# Hydro            147.171551   549.809328   1.0  22500.00
# Nuclear         2091.855179  1303.509273  20.0   8212.00
# Oil              112.878754   392.009039   1.0   6794.00
# Other             84.020000   145.891392   4.5    845.26
# Petcoke          202.048125   476.986459   4.7   1707.30
# Solar             17.657039    41.939412   1.0   1021.00
# Storage           12.683704    35.574631   1.0    400.00
# Waste             13.809657    20.582503   1.0    160.90
# Wave and Tidal    55.220000   101.440708   1.0    254.00
# Wind              49.224126   106.138355   1.0   6000.00

# %%
from matplotlib import pyplot as plt

# Assuming '_df_9' is your DataFrame with 'primary_fuel' as the index and 'amin' and 'amax' columns
plt.figure(figsize=(12, 8))

# Plot 'amin'
_df_9['amin'].plot(kind='line', marker='o', linestyle='-', color='b', label='Minimum Power Output (amin)')

# Plot 'amax'
_df_9['amax'].plot(kind='line', marker='o', linestyle='-', color='r', label='Maximum Power Output (amax)')

plt.title('Power Output Range (amin and amax) by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Power Output')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()  # Add legend to differentiate between 'amin' and 'amax'
plt.show()

# %%
solar_capacity = data[data['primary_fuel'] == 'Solar']['capacity_mw'].sum()
oil_capacity = data[data['primary_fuel'] == 'Oil']['capacity_mw'].sum()


labels = ['Solar', 'Oil']
sizes = [solar_capacity, oil_capacity]
colors = ['yellow','black']
explode = (0.1, 0)
plt.figure(figsize=(10, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, explode=explode)
plt.title('Total Power Output Comparison between Solar and Oil Power Plants')
plt.show()

# %%
time_trends = data.groupby('year_of_capacity_data').size()
time_trends.plot(kind='line', color='blue', marker='o', linestyle='-')
plt.title('Power Plant Capacity Trends over Time')
plt.xlabel('Year')
plt.ylabel('Number of Power Plants')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='latitude', y='longitude', data=data, hue='primary_fuel')
plt.title('Geographical Distribution of Power Plants')
plt.show()
