# %% [markdown]
# <a href="https://colab.research.google.com/github/Ester-Taniya/DI-Bootcamp/blob/main/Week5%20/Day1/Exercises_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🌟 Exercise 1 : Understanding Data Visualization
# #1 Explain why data visualization is important in data analysis.
#
# Data visualization gives a simpler, understandable, and accessible form to explore data mining
# In  analyzing complex data it's identifying:
# patterns and trends,  corelations, anomalies and extracting valuable insights
# so it helps make a decision to next strategy
#
# #2 Describe the purpose of a line graph in data visualization.
#
# Line charts are often used to display changes in a variable over time
# it can be used  for   single or  for multiple variables (to compare the trends)
# Graphs help highlight Critical Points or events, such as peaks, troughs, or other changes that may be important to the analysis.
# Also in analyzing time series data, linear trends can be used to forecast future values.

# %% [markdown]
# 🌟 Exercise 2 : Creating A Line Plot For Temperature Variation
#
# Instructions
#
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import matplotlib.pyplot as plt

temp = [72, 74, 76, 80, 82, 78, 75]
week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

plt.plot(week, temp, marker='o')

plt.xlabel('Day')
plt.ylabel('Temperature (°F)')

plt.title('Temperature Variations Over a Week')

plt.show()

# %% [markdown]
# 🌟 Exercise 3 : Visualizing Monthly Sales With A Bar Chart
#
# Instructions
#
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
import matplotlib.pyplot as plt

sales = [5000, 5500, 6200, 7000, 7500]
month = ['January', 'February', 'March', 'April', 'May']
plt.bar(month, sales, color='red')


plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')

plt.title('Monthly Sales for a Retail Store')

plt.show()

# %% [markdown]
# 🌟 Exercise 4 : Data Visualisation
#
# Instructions
#
# Using the dataset sales_data.csv
#
# Calculate the total quantity of products sold by the company.
# Identify the category that had the highest revenue and calculate how much revenue it generated.
# Determine the average revenue per sale in the dataset.
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
import pandas as pd
import matplotlib.pyplot as plt

data= pd.read_csv('sales_data.csv')
data.head(20)
# Out:
#           date     product     category   price  quantity  revenue
# 0   2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1   2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2   2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3   2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4   2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# 5   2022-01-05       Watch  Accessories   150.0      10.0   1500.0
# 6   2022-01-06  Smartphone  Electronics   600.0       8.0   4800.0
# 7   2022-01-06      Tablet  Electronics   400.0       5.0   2000.0
# 8   2022-01-07        Coat     Clothing   100.0      10.0   1000.0
# 9   2022-01-08  Smartwatch  Accessories   200.0      12.0   2400.0
# 10  2022-01-09     Speaker  Electronics    80.0      15.0   1200.0
# 11  2022-01-10    Backpack         Bags    50.0      20.0   1000.0
# 12  2022-01-11      Hoodie     Clothing    40.0      30.0   1200.0
# ...

# %%
#the total quantity of products sold by the company.
gruped_quantity=data['quantity'].groupby(data['product']).count()

print('total quantity of products sold by the company :', gruped_quantity.sum() )
# Out:
# total quantity of products sold by the company : 368

# %%
# category that had the highest revenue
gd = data['revenue'].groupby(data['category']).sum()

max_product = gd.idxmax()
max_revenue =gd.max()

print(f"The product with the maximum revenue is {max_product} : {max_revenue}.")
# Out:
# The product with the maximum revenue is Electronics : 516080.0.

# %%
#the average revenue per sale in the dataset. (if each sale it's a group of rows by date  )
data['revenue'].groupby(data['date']).mean()

# if we need to determine the average revenue for alll dataset
data['revenue'].mean()
# Out:
# 2060.679347826087

# %%
import matplotlib.pyplot as plt

data['date'] = pd.to_datetime(data['date'])
data['Quarter'] = data['date'].dt.quarter


quarter_labels = {1: 'Q1', 2: 'Q2', 3: 'Q3', 4: 'Q4'}
data['Quarter'] = data['Quarter'].map(quarter_labels)


revenue_by_quarter = data.groupby('Quarter')['revenue'].sum()


plt.bar(revenue_by_quarter.index, revenue_by_quarter)
plt.xlabel('Quarter')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Quarter')
plt.show()

# %% [markdown]
# 🌟 Exercise 5 : Data Visualisation Using MatPlotLib
#
# Instructions
#
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
#Plot the function y = x^2 for x values ranging from -10 to 10

x=list(range(-10,11))
y=[i**2 for i in x]
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(title='Plot the function y = x^2 for x values (from -10 to 10)', xlabel='x_values', ylabel='y_values')

plt.show()

# %%
#bar chart to display the sales data of four different products (A, B, C, D)

import matplotlib.pyplot as plt
products = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]

plt.bar(products, sales, color= 'green')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Sales Data of Four Products in a Week')

plt.show()

# %%
# a pie chart representing the following data about favorite fruits

import matplotlib.pyplot as plt

fruits = ['Apple', 'Bananas', 'Cherries', 'Dates']
procents = [40, 30, 20, 10]

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(procents, labels=fruits, autopct='%1.1f%%')
plt.legend(title='Favorite Fruits')

plt.title('Favorite fruits of a group of people')
plt.show()
