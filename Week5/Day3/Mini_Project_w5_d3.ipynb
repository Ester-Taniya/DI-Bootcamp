# %% [markdown]
# <a href="https://colab.research.google.com/github/Ester-Taniya/DI-Bootcamp/blob/main/Week5/Day3/Mini_Project_w5_d3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
url = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv'
penguins = pd.read_csv(url)
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
#cheack nan rows
nan_rows = penguins.isna().any(axis=1)
penguins[nan_rows]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %%
# we can drop rows where(bill_length_mm,	bill_depth_mm,	flipper_length_mm,	body_mass_g	) is NaN
#it isn't posible to fild
penguins = penguins.dropna(subset=['bill_length_mm'])

# %%
# can fill van values in sex column based on average body_mass_g
penguins[penguins['sex'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
#
#      body_mass_g  sex  year
# 8         3475.0  NaN  2007
# 9         4250.0  NaN  2007
# 10        3300.0  NaN  2007
# 11        3700.0  NaN  2007
# 47        2975.0  NaN  2007
# 178       4100.0  NaN  2007
# 218       4650.0  NaN  2008
# ...

# %%
penguins['species'][penguins['sex'].isna()].unique()
# Out:
# array(['Adelie', 'Gentoo'], dtype=object)

# %%
male_median_weight=  penguins['body_mass_g'][penguins['sex'] == 'male'].groupby(penguins['species']).median()
male_median_weight
# Out:
# species
# Adelie       4000.0
# Chinstrap    3950.0
# Gentoo       5500.0
# Name: body_mass_g, dtype: float64

# %%
female_median_weight=penguins['body_mass_g'][penguins['sex'] == 'female'].groupby(penguins['species']).median()
female_median_weight
# Out:
# species
# Adelie       3400.0
# Chinstrap    3550.0
# Gentoo       4700.0
# Name: body_mass_g, dtype: float64

# %%
#cheack nan rows
penguins[penguins['sex'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
#
#      body_mass_g  sex  year
# 8         3475.0  NaN  2007
# 9         4250.0  NaN  2007
# 10        3300.0  NaN  2007
# 11        3700.0  NaN  2007
# 47        2975.0  NaN  2007
# 178       4100.0  NaN  2007
# 218       4650.0  NaN  2008
# ...

# %%
import numpy as np

# Assuming 'penguins' is your DataFrame
# Assuming 'female_median_weight' is a Series or DataFrame containing the median weights for each species

adelie_filter = (penguins['species'] == 'Adelie') & (penguins['body_mass_g'] > female_median_weight.loc['Adelie']) & (penguins['sex'].isna())
penguins.loc[adelie_filter, 'sex'] = penguins.loc[adelie_filter, 'sex'].fillna('male')
adelie_filter = (penguins['species'] == 'Adelie') & (penguins['body_mass_g'] < male_median_weight.loc['Adelie']) & (penguins['sex'].isna())
penguins.loc[adelie_filter, 'sex'] = penguins.loc[adelie_filter, 'sex'].fillna('female')

adelie_filter = (penguins['species'] == 'Gentoo') & (penguins['body_mass_g'] > female_median_weight.loc['Gentoo']) & (penguins['sex'].isna())
penguins.loc[adelie_filter, 'sex'] = penguins.loc[adelie_filter, 'sex'].fillna('male')
adelie_filter = (penguins['species'] == 'Gentoo') & (penguins['body_mass_g'] < male_median_weight.loc['Gentoo']) & (penguins['sex'].isna())
penguins.loc[adelie_filter, 'sex'] = penguins.loc[adelie_filter, 'sex'].fillna('female')

# %%
penguins[penguins['sex'].isna()]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
summary_statistics = penguins.describe()
summary_statistics
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   342.000000
# mean   2008.029240
# std       0.817168
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
unique_values = penguins.nunique()
unique_values
# Out:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# year                   3
# dtype: int64

# %%
penguins.max()
# Out:
# species                 Gentoo
# island               Torgersen
# bill_length_mm            59.6
# bill_depth_mm             21.5
# flipper_length_mm        231.0
# body_mass_g             6300.0
# sex                       male
# year                      2009
# dtype: object

# %%
penguins.min()
# Out:
# species              Adelie
# island               Biscoe
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# sex                  female
# year                   2007
# dtype: object

# %% [markdown]
# Visualization Tasks:
# Species Distribution: Use a bar chart to show the distribution of penguin species.

# %%
data_distribution = penguins['species'].value_counts()
data_distribution
# Out:
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: species, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(data_distribution.index, data_distribution.values)
plt.title('Penguin Species Distribution')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - Flipper Length vs. Body Mass: Create a scatter plot to analyze the relationship between flipper length and body mass, color-coded by species.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', hue='species', data=penguins, palette='viridis')
plt.title('Flipper Length vs. Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.legend()
plt.show()

# %% [markdown]
# - Island Distribution: Visualize the count of penguins on each island using a pie chart.

# %%
plt.figure(figsize=(8, 8))
df['island'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Island Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# - Sex Distribution within Species: Create grouped bar charts showing the distribution of sex within each penguin species.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='species', hue='sex', data=df)
plt.title('Sex Distribution within Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - Heatmap of Correlations: Plot a heatmap to visualize the correlations between numerical variables.

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Heatmap of Correlations')
plt.show()
# Out:
# <ipython-input-24-427e152016fa>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# - Boxplots for Measurements: Generate boxplots for flipper length, body mass, and bill measurements, segmented by species.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
sns.boxplot(x='species', y='flipper_length_mm', data=df, ax=axes[0])
sns.boxplot(x='species', y='body_mass_g', data=df, ax=axes[1])
sns.boxplot(x='species', y='bill_depth_mm', data=df, ax=axes[2])
plt.suptitle('Boxplots for Measurements by Species')
plt.show()

# %% [markdown]
# - Histograms of Measurements: Create histograms to show the distribution of key measurements (bill length, bill depth, flipper length).

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
sns.histplot(df['bill_length_mm'], kde=True, bins=20, ax=axes[0])
sns.histplot(df['bill_depth_mm'], kde=True, bins=20, ax=axes[1])
sns.histplot(df['flipper_length_mm'], kde=True, bins=20, ax=axes[2])
plt.suptitle('Histograms of Measurements')
plt.show()
